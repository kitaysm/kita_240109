# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pit
import seaborn as sns

tips = pd.read_csv('/content/drive/MyDrive/ktd231026/m3_분석라이브러리/시각화2/tips.csv')
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   smoker      244 non-null    object
#  3   day         244 non-null    object
#  4   time        244 non-null    object
#  5   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 11.6+ KB

# %%
# 빈도표

party_counts = pd.crosstab(tips['day'],tips['size'])
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
pd.pivot_table(tips, index='day', columns='size', values='total_bill', aggfunc='count', fill_value=0)
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
pc_25 = party_counts.loc[:,2:5]  # loc를 썼다는 건 2와5가 숫자가 아니라 이름인덱스임. 따라서 2부터5까지출력
pc_25
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
pc_25.sum(1)
# Out:
# day
# Fri     18
# Sat     85
# Sun     75
# Thur    58
# dtype: int64

# %%
# pc_25 각 열방향 합계 1로 정규화
pc_25.apply(lambda x : x/pc_25.sum(1))
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %% [markdown]
# 팁이 10이고 총 청구 금액이 100인 경우, 팁의 퍼센트를 마크업과 마진으로 계산한 결과는 다음과 같습니다:
#
# 마크업 (Markup): 약 11.11%
# - 마크업은 기본 비용에 대한 추가 비용(여기서는 팁)의 비율
# - Tip / (Total Bill - Tip) x 100
#
# 마진 (Margin): 10%
# - 마진은 전체 판매 가격(여기서는 총 청구 금액)에 대한 추가 비용(팁)의 비율
# - Tip / Total Bill x 100
#
# 마크업은 순수한 비용(총 금액에서 팁을 제외한 금액)에 대한 추가 비용의 비율을, 마진은 전체 금액에 대한 추가 비용의 비율

# %%
# 요일별 팁의 비중을 시각화(수평 막대그래프)
import seaborn as sns
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip']) # tip 비중
print(tips.head())
sns.barplot(x='tip_pct', y='day', data=tips, orient='h', errorbar=None) # errorbar는 오차 막대를 제어
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069
# <Axes: xlabel='tip_pct', ylabel='day'>

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h', errorbar=None)
# Out:
# <Axes: xlabel='tip_pct', ylabel='day'>

# %%
pc_25
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
party_counts
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
# countplot()
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.countplot(x='size', data=tips, hue='time', palette='bone')
plt.title("Count Plot")
plt.show()

# %%
# np.random.normal(loc, scale, size) : 정규분표 난수 샘플
comp1 = np.random.normal(0, 1, size=200)
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1,comp2]))
values.describe()
# Out:
# count    400.000000
# mean       5.089096
# std        5.282772
# min       -2.908592
# 25%        0.068953
# 50%        4.770868
# 75%       10.051155
# max       15.803860
# dtype: float64

# %%
sns.histplot(values, bins=100, color='k', kde=True)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Q. 두 개의 정규분포를 따르는 상이한 데이터 셋을 생성한 후 하나의 데이터 셋으로 병합한 후 시각화하여 데이터의 분포를 확인하세요.

# %%
fish_multi = pd.read_csv('/content/drive/MyDrive/ktd231026/m3_분석라이브러리/시각화1/4_fm2.csv')
fish_multi.head()
# Out:
#   species  length
# 0       A       2
# 1       A       3
# 2       A       3
# 3       A       4
# 4       A       4

# %%
length_a = fish_multi.query('species=="A"')['length']
length_b = fish_multi.query('species=="B"')['length']
sns.histplot(length_a, bins=5, color='gray', kde=True)
sns.histplot(length_b, bins=5, color='skyblue', kde=True)
# Out:
# <Axes: xlabel='length', ylabel='Count'>

# %%
# Q. box plot으로 A, B 비교
sns.boxplot(x= 'species', y='length', data=fish_multi, color='gray')
# Out:
# <Axes: xlabel='species', ylabel='length'>

# %%
# 바이올린 플롯
# 커널 밀도추출의 결과를 y축 방향에 추가하여 데이터가 퍼져있는 분산의 정도 파악
sns.violinplot(x='species', y='length', data=fish_multi, color='skyblue')
# Out:
# <Axes: xlabel='species', ylabel='length'>

# %%
cov_data = pd.read_csv('/content/drive/MyDrive/ktd231026/m3_분석라이브러리/시각화2/4_cov.csv')
cov_data
# Out:
#       x   y
# 0  18.5  34
# 1  18.7  39
# 2  19.1  41
# 3  19.7  38
# 4  21.5  45
# 5  21.7  41
# 6  21.8  52
# 7  22.0  44
# 8  23.4  44
# 9  23.8  49

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.jointplot(x='x',y='y', data=cov_data, kind='reg')
plt.show()

# %% [markdown]
# sns.lmplot과 sns.regplot 차이점
#
# 기능적 차이:
# - sns.lmplot: 이 함수는 FacetGrid를 사용하여 데이터를 다양한 카테고리별로 분할하여 여러 서브플롯을 만들 수 있다. 이는 데이터의 서브셋에 대한 회귀선을 별도로 그릴 수 있음을 의미.
# sns.regplot: 이 함수는 단일 축 객체(ax)에 회귀선을 그리는 데 사용. 간단하고, 한 번에 하나의 관계만 표시.
#
# 입력 매개변수의 차이:
# - sns.lmplot은 data 매개변수를 통해 DataFrame을 입력받으며, x와 y는 문자열로 열 이름을 지정.
# - sns.regplot에서는 x와 y가 DataFrame의 열이거나 NumPy 배열일 수 있으며, data 매개변수는 선택사항.
#
# 사용상의 유연성:
# - sns.lmplot은 regplot보다 더 많은 매개변수를 제공하여, 데이터를 세분화하고 다양한 방식으로 표시.
# - sns.regplot은 더 단순하고 직관적인 옵션을 제공하여, 빠르고 간편하게 선형 회귀선을 그릴 수 있게 한다.
#
# 그래픽 표현의 차이:
# - sns.lmplot은 내부적으로 FacetGrid를 사용하므로, 플롯의 구성과 스타일을 더 세밀하게 조정할 수 있다.
# - sns.regplot은 주로 간단한 선형 관계를 표시하는데 적합하며, 복잡한 그래픽 설정은 제한적.

# %%
# 'x'와 'y'열을 데이터 포인트로 사용하고, 'category' 열에 따라 서로 다른 색상의 선형 회귀선을 그렸습니다.
# 각 카테고리('A'와'B')에 대한 회귀선이 서로 다른 색상으로 표시
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 임의의 데이터 생성
np.random.seed(0)
data = pd.DataFrame({
    'x': np.random.rand(50),
    'y': np.random.rand(50),
    'category': np.random.choice(['A', 'B'], 50)
})

# %%
# sns.implot 사용 예시
sns.lmplot(x='x', y='y', data=data, hue='category')
plt.title('sns.Implot Example')
plt.show()

# sns.regplot 사용 예시
plt.figure(figsize=(6,4))
sns.regplot(x='x', y='y', data=data)
plt.title('sns.regplot Example')
plt.show()

# %% [markdown]
# auto-mpg 데이터 셋에서 mpg와 weight의 선형 관계를 그래프로 작성하세요.(전체, orgin에 따른 관계)

# %%
import pandas as pd
df_auto = pd.read_excel('/content/drive/MyDrive/ktd231026/m3_분석라이브러리/시각화1/auto-mpg.xlsx')
df_auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
sns.boxplot(data=df_auto.mpg)
# Out:
# <Axes: ylabel='mpg'>

# %%
sns.boxplot(data=df_auto, x='mpg')
# Out:
# <Axes: xlabel='mpg'>

# %%
sns.violinplot(data=df_auto.mpg)
# Out:
# <Axes: ylabel='mpg'>

# %%
sns.violinplot(data=df_auto, x='mpg')
# Out:
# <Axes: xlabel='mpg'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.lmplot(x='mpg', y='weight', data=df_auto, hue='origin')
plt.title('df_auto lmplot Example')
plt.show()

plt.figure(figsize=(6,4))
sns.regplot(x='mpg', y='weight', data=df_auto)
plt.title('df_auto.regplot Example')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 데이터프레임 df_auto 정의 필요 (예: sns.load_dataset('mpg') 사용 가능)

# mpg와 weight의 관계, 1행 2열로 표시
# 첫 번째 열 : 전체 데이터에 대한 그래프
sns.lmplot(x='mpg', y='weight', data=df_auto, col='origin', col_wrap=3) # col_wrap=3는 한 행에 최대 3개의 그래프를 표시하도록 설정

plt.show()

# %%
sns.pairplot(df_auto[['mpg','weight','displacement']], palette='rainbow')

# %%
t_df = sns.load_dataset('titanic')
t_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
t_df[['pclass','age','fare','survived']].corr()
# Out:
#             pclass       age      fare  survived
# pclass    1.000000 -0.369226 -0.549500 -0.338481
# age      -0.369226  1.000000  0.096067 -0.077221
# fare     -0.549500  0.096067  1.000000  0.257307
# survived -0.338481 -0.077221  0.257307  1.000000

# %%
sns.heatmap(t_df[['pclass','age','fare','survived']].corr(),annot=True)
plt.title('Heatmap of the Dataset',fontsize=20)
# Out:
# Text(0.5, 1.0, 'Heatmap of the Dataset')

# %% [markdown]
# Q. sex와 class간의 생존율을 보여주는 히트맵을 작성하세요

# %%
pivot = pd.pivot_table(t_df,index='class',
               columns='sex',
               values='survived',
               aggfunc=(lambda x:x.sum()/x.count()),fill_value=0)
sns.heatmap(pivot,annot=True)
# Out:
# <Axes: xlabel='sex', ylabel='class'>

# %%
table= t_df.pivot_table(index=['sex'], columns=['class'], values=['survived'], aggfunc='mean')
table
# Out:
#         survived
# class      First    Second     Third
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
sns.heatmap(table, annot=True, fmt='f', cmap='coolwarm', # YlGnBu plasma viridis
            linewidth=5, cbar=True)
# Out:
# <Axes: xlabel='None-class', ylabel='sex'>

# %% [markdown]
# sns.lineplot() 함수에서는 err_style 매개변수를 이용해 밴드의 스타일을 조정할 수 있습니다.
#
# 예를 들어, err_style="band" 로 설정하면, 투명한 밴드가 그려지고, err_style='bars'로 설정하면, 오차 막대(error bar)가 그려집니다.

# %%
plt.figure(figsize=(6,4))
sns.lineplot(data=df_auto, x="model year", y="mpg", hue="origin", err_style="band", palette=['red','green','blue'])
# Out:
# <Axes: xlabel='model year', ylabel='mpg'>

# %%
fish_data = np.array([5,7,9,1,5,6,6,2,4,4,5,6,7,3,8,10])

# %%
fig = plt.figure(figsize=(8,4))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)
sns.histplot(fish_data, color='skyblue', kde=False, ax=ax1)
sns.histplot(fish_data, color='skyblue', kde=True, ax=ax2)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# Q1_0117. 타이타닉 데이터셋(sns.load_dataset("titanic"))을 사용하여, 클래스(class)별 승객 수를 나타내는 막대 그래프를 생성하세요
# - 각 막대 위에 승객 수 표시

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 타이타닉 데이터셋 로드
titanic = sns.load_dataset("titanic")

# 클래스별 승객 수 카운트
class_counts = titanic['class'].value_counts()

# 막대 그래프 생성
plt.figure(figsize=(8, 6))
sns.barplot(x=class_counts.index, y=class_counts.values)

# 현재 축(ax) 가져오기
ax = plt.gca()

# 각 막대 위에 승객 수 표시
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=12, color='black',
                xytext=(0, 5), # 주석 텍스트를 막대의 정상부 중앙에서 바로 위로 조금 올려서 표시
                textcoords='offset points')

# 제목 및 레이블 설정
plt.title('Passenger Count by Class on Titanic')
plt.xlabel('Class')
plt.ylabel('Number of Passengers')

# 그래프 표시
plt.show()

# %%
df = sns.load_dataset('titanic')
counts = df['class'].value_counts()
plt.figure(figsize=(8,6))
barplot = sns.barplot(x=counts.index, y=counts.values)
barplot.bar_label(barplot.containers[0])
plt.title('Passenger Count by Class on Titanic')
plt.xlabel('Class')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# Q2_0117. sns.load.dataset('flights')을 로드하고, 이를 피벗 테이블로 변환하여 연도별 월간 승객 수를 나타내세요. 이 데이터를 사용하여 히트맵을 생성하세요. 색상 맵은 자유롭게 선택

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 'flights' 데이터셋 로드
flights = sns.load_dataset('flights')

# 피벗 테이블 생성
pivot_flights = flights.pivot("month", "year", "passengers")

# 히트맵 생성
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_flights, annot=True, fmt="d", cmap="YlGnBu")

# 제목 설정
plt.title('Monthly Passengers by Year (Flights Dataset)')

# 그래프 표시
plt.show()

# %% [markdown]
# Q3_0117. sns.load_dataset('penguins')을 사용하여 페어플롯(pairplot)을 생성하세요. 종(species)에 따라 다른 색상을 사용

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 'penguins' 데이터셋 로드
penguins = sns.load_dataset('penguins')

# 페어플롯 생성, 종(species)에 따라 색상 구분
sns.pairplot(penguins, hue='species', palette='rainbow')

# 제목 설정
plt.suptitle('Pairplot of Penguins Dataset by Species', y=1.02)  # y=1.02는 제목이 그래프와 겹치지 않도록 조정

# 그래프 표시
plt.show()

# %% [markdown]
# Q4_0117. 타이타닉 데이터셋을 사용하여, 객실 등급(class)에 따른 탑승객의 나이를 나타내는 박스 플롯과 바이올린 플롯을 같은 그래프 내에서 나란히 생성하세요. 이를 통해 각 클래스별 나이 분포의 차이를 비교하세요

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 타이타닉 데이터셋 로드
titanic = sns.load_dataset("titanic")

# 그래프 생성을 위한 그림판 설정
plt.figure(figsize=(12, 6))

# 박스 플롯 생성
plt.subplot(1, 2, 1)
sns.boxplot(x="class", y="age", data=titanic)
plt.title("Box Plot of Age by Class")

# 바이올린 플롯 생성
plt.subplot(1, 2, 2)
sns.violinplot(x="class", y="age", data=titanic)
plt.title("Violin Plot of Age by Class")

# 그래프 표시
plt.show()

# %% [markdown]
# Q5_0117. 펭귄 데이터셋을 사용하여, 각 종별로 섬(island) 별 개체수를 나타내는 카운트 플롯을 생성하세요. x축은 'island' hue는 'species'로 설정하세요

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 'penguins' 데이터셋 로드
penguins = sns.load_dataset('penguins')

# 카운트 플롯 생성
plt.figure(figsize=(10, 6))
sns.countplot(x='island', hue='species', data=penguins)

# 제목 설정
plt.title('Penguin Count by Island and Species')

# 그래프 표시
plt.show()
